# %%
import numpy as np
from scipy import optimize
from sympy import nsolve
import matplotlib.pyplot as plt



# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# local modules
from Funcs import *
from Model import *
model = production_economy()
model.setup()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Question 1
# We first find the market clearing conditions, i.e. the value of $l^\star$, for the different prices defined as $p_1$ in `linspace(0.1,2.0,10)` and $p_2$ in `linspace(0.1,2.0,10)`.

# %%
# Define the linspaces
p1_value = np.linspace(0.1, 2.0, 10)
p2_value = np.linspace(0.1, 2.0, 10)

# Empty array to store results
results = []

for p1 in p1_value:
    for p2 in p2_value:
        if model.market_clearing(p1, p2) != None:
            labor, good1, good2 = model.market_clearing(p1, p2)
            results.append([p1, p2, labor, good1, good2])

            # Print the results
            for result in results:
                p1, p2, labor, good1, good2 = result
                # print(f"p1: {p1:.2f}, p2: {p2:.2f}, Labor MC: {labor:.4f}, Good1 MC: {good1:.4f}, Good2 MC: {good2:.4f}")

# Print number of markets clearing
print(f"Number of markets not clearing: {len(p1_value)*len(p2_value) - len(results)}")
print(f"Number of markets clearing: {len(results)}")
# Out:
# Prices of good 1: 0.1
# Prices of good 2: 0.1
# Excess demand: [0.095      2.96000834 6.97335279]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 0.3111111111111111
# Excess demand: [0.17885802 3.0036313  2.13466792]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 0.5222222222222223
# Excess demand: [0.2404321  3.09299709 1.14320674]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 0.7333333333333333
# Excess demand: [0.27972222 3.22995033 0.67695389]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 0.9444444444444444
# Excess demand: [0.2967284  3.41709192 0.38435343]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 1.1555555555555557
# Excess demand: [0.29145062 3.65757128 0.17086642]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 1.3666666666666667
# Excess demand: [2.63888889e-01 3.95483660e+00 4.19256647e-04]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.21404321  4.31236462 -0.14375046]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.14191358  4.73340997 -0.2705214 ]
# Markets does not clear
# Prices of good 1: 0.1
# Prices of good 2: 2.0
# Excess demand: [ 0.0475      5.22080635 -0.38507259]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 0.1
# Excess demand: [0.17885802 0.82596879 7.07513968]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 0.3111111111111111
# Excess demand: [0.26271605 0.84008953 2.16761631]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 0.5222222222222223
# Excess demand: [0.32429012 0.86901062 1.16310854]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 0.7333333333333333
# Excess demand: [0.36358025 0.91331599 0.69140819]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 0.9444444444444444
# Excess demand: [0.38058642 0.97382826 0.39585318]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 1.1555555555555557
# Excess demand: [0.37530864 1.05154293 0.18052768]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 1.3666666666666667
# Excess demand: [0.34774691 1.14754926 0.00883074]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.29790123  1.26294554 -0.13624519]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.2257716   1.39875653 -0.2637091 ]
# Markets does not clear
# Prices of good 1: 0.3111111111111111
# Prices of good 2: 2.0
# Excess demand: [ 0.13135802  1.55587977 -0.37881236]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 0.1
# Excess demand: [0.2404321  0.34073939 7.28365983]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 0.3111111111111111
# Excess demand: [0.32429012 0.34926874 2.23509886]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 0.5222222222222223
# Excess demand: [0.3858642  0.36673013 1.20385179]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 0.7333333333333333
# Excess demand: [0.42515432 0.39346057 0.72098021]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 0.9444444444444444
# Excess demand: [0.44216049 0.42993424 0.41936178]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 1.1555555555555557
# Excess demand: [0.43688272 0.47672434 0.20026025]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 1.3666666666666667
# Excess demand: [0.40932099 0.53445717 0.02599448]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.35947531  0.60376344 -0.12094587]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.28734568  0.68523194 -0.24983396]
# Markets does not clear
# Prices of good 1: 0.5222222222222223
# Prices of good 2: 2.0
# Excess demand: [ 0.1929321   0.77937829 -0.3660722 ]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 0.1
# Excess demand: [0.27972222 0.08059929 7.6032174 ]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 0.3111111111111111
# Excess demand: [0.36358025 0.08679399 2.33847804]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 0.5222222222222223
# Excess demand: [0.42515432 0.09946771 1.26622281]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 0.7333333333333333
# Excess demand: [0.46444444 0.11884901 0.76620324]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 0.9444444444444444
# Excess demand: [0.48145062 0.14525895 0.45526654]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 1.1555555555555557
# Excess demand: [0.47617284 0.17908512 0.23035468]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 1.3666666666666667
# Excess demand: [0.44861111 0.2207501  0.05213156]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.39876543  0.27067893 -0.0976831 ]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.3266358   0.32926869 -0.22876715]
# Markets does not clear
# Prices of good 1: 0.7333333333333333
# Prices of good 2: 2.0
# Excess demand: [ 0.23222222  0.39686805 -0.34675363]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 0.1
# Excess demand: [ 0.2967284  -0.10511837  8.03988108]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 0.3111111111111111
# Excess demand: [ 0.38058642 -0.10018991  2.47967335]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 0.5222222222222223
# Excess demand: [ 0.44216049 -0.09011479  1.35132805]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 0.7333333333333333
# Excess demand: [ 0.48145062 -0.07472704  0.82782644]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 0.9444444444444444
# Excess demand: [ 0.49845679 -0.05379379  0.5041108 ]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 1.1555555555555557
# Excess demand: [ 0.49317901 -0.02703461  0.27121783]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 1.3666666666666667
# Excess demand: [0.46561728 0.00585594 0.08755151]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.4157716   0.04518412 -0.0662204 ]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.34364198  0.09123721 -0.20032775]
# Markets does not clear
# Prices of good 1: 0.9444444444444444
# Prices of good 2: 2.0
# Excess demand: [ 0.2492284   0.14426976 -0.32071717]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 0.1
# Excess demand: [ 0.29145062 -0.25693026  8.60099967]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 0.3111111111111111
# Excess demand: [ 0.37530864 -0.25278972  2.66100758]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 0.5222222222222223
# Excess demand: [ 0.43688272 -0.24433291  1.46050495]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 0.7333333333333333
# Excess demand: [ 0.47617284 -0.2314353   0.90675417]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 0.9444444444444444
# Excess demand: [ 0.49317901 -0.21392252  0.56654888]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 1.1555555555555557
# Excess demand: [ 0.48790123 -0.19158477  0.32333925]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 1.3666666666666667
# Excess demand: [ 0.46033951 -0.16419466  0.13262468]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.41049383 -0.13152285 -0.02627483]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.3383642  -0.09335418 -0.16429873]
# Markets does not clear
# Prices of good 1: 1.1555555555555557
# Prices of good 2: 2.0
# Excess demand: [ 0.24395062 -0.04949805 -0.28780067]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 0.1
# Excess demand: [ 0.26388889 -0.39029651  9.29461871]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 0.3111111111111111
# Excess demand: [ 0.34774691 -0.38669159  2.88502234]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 0.5222222222222223
# Excess demand: [ 0.40932099 -0.3793357   1.59521489]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 0.7333333333333333
# Excess demand: [ 0.44861111 -0.36813409  1.00397245]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 0.9444444444444444
# Excess demand: [ 0.46561728 -0.35295412  0.64329349]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 1.1555555555555557
# Excess demand: [ 0.46033951 -0.33363704  0.3872495 ]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 1.3666666666666667
# Excess demand: [ 0.43277778 -0.31000966  0.18775525]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.3829321  -0.28189786  0.0224631 ]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.31080247 -0.24913668 -0.12044172]
# Markets does not clear
# Prices of good 1: 1.3666666666666667
# Prices of good 2: 2.0
# Excess demand: [ 0.21638889 -0.2115828  -0.24781998]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 0.1
# Excess demand: [ 0.21404321 -0.51240099 10.12885083]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 0.3111111111111111
# Excess demand: [ 0.29790123 -0.50918445  3.15428033]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 0.5222222222222223
# Excess demand: [ 0.35947531 -0.50262759  1.7569295 ]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 0.7333333333333333
# Excess demand: [ 0.39876543 -0.49265784  1.12047306]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 0.9444444444444444
# Excess demand: [ 0.4157716  -0.47917382  0.73505926]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 1.1555555555555557
# Excess demand: [ 0.41049383 -0.46205429  0.46348373]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 1.3666666666666667
# Excess demand: [ 0.3829321  -0.44116661  0.25334945]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.33308642 -0.41637653  0.08030663]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.26095679 -0.38755973 -0.06852067]
# Markets does not clear
# Prices of good 1: 1.577777777777778
# Prices of good 2: 2.0
# Excess demand: [ 0.16654321 -0.35460179 -0.20059004]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 0.1
# Excess demand: [ 0.14191358 -0.62704886 11.11128994]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 0.3111111111111111
# Excess demand: [ 0.2257716  -0.6241293   3.47117268]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 0.5222222222222223
# Excess demand: [ 0.28734568 -0.61818281  1.94702269]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 0.7333333333333333
# Excess demand: [ 0.3266358  -0.60915418  1.25718249]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 0.9444444444444444
# Excess demand: [ 0.34364198 -0.59696586  0.84251645]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 1.1555555555555557
# Excess demand: [ 0.3383642  -0.58152485  0.55254395]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 1.3666666666666667
# Excess demand: [ 0.31080247 -0.56272899  0.32979218]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.26095679 -0.54047711  0.14754582]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.18882716 -0.51467018 -0.0083045 ]
# Markets does not clear
# Prices of good 1: 1.788888888888889
# Prices of good 2: 2.0
# Excess demand: [ 0.09441358 -0.48521993 -0.14593329]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 0.1
# Excess demand: [ 0.0475     -0.73645968 12.24854818]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 0.3111111111111111
# Excess demand: [ 0.13135802 -0.73377673  3.83779353]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 0.5222222222222223
# Excess demand: [ 0.1929321  -0.72831666  2.1666975 ]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 0.7333333333333333
# Excess demand: [ 0.23222222 -0.72003727  1.41491434]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 0.9444444444444444
# Excess demand: [ 0.2492284  -0.70887879  0.96625907]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 1.1555555555555557
# Excess demand: [ 0.24395062 -0.69477171  0.65487492]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 1.3666666666666667
# Excess demand: [ 0.21638889 -0.67763714  0.41741791]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 1.577777777777778
# Excess demand: [ 0.16654321 -0.65739573  0.22444769]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 1.788888888888889
# Excess demand: [ 0.09441358 -0.63397141  0.06041275]
# Markets does not clear
# Prices of good 1: 2.0
# Prices of good 2: 2.0
# Excess demand: [ 0.         -0.60729489 -0.08368807]
# Markets does not clear
# Number of markets not clearing: 100
# Number of markets clearing: 0

# %% [markdown]
# # Question 2
# We now want to find the equilibrium prices p1 and p2 that ensures market clearing.
# We will use Walras' law such that by having 2 markets lcear, the clearing of market 3 is ensured.

# %%
initial_guess = [model.par.p1, model.par.p2]

equilibrium_prices = optimize.fsolve(Walras_law, initial_guess, args=(model.par.tau, model.par.T, model.par))

# Print the results
p1_equilibrium, p2_equilibrium = equilibrium_prices
model.par.p1 = p1_equilibrium
model.par.p2 = p2_equilibrium
print(f"Equilibrium prices: p1 = {p1_equilibrium:.4f}, p2 = {p2_equilibrium:.4f}")

# Calculate the equilibrium values
laborD_eq = labor_demand(model.par, p1_equilibrium) + labor_demand(model.par, p2_equilibrium)
laborS_eq = labor_supply(model.par, p1_equilibrium, p2_equilibrium, model.par.tau, model.par.T)
good1_eq, good2_eq = demand(model.par, p1_equilibrium, p2_equilibrium, model.par.tau, model.par.T)
y1_eq = production(model.par, p1_equilibrium)
y2_eq = production(model.par, p2_equilibrium)

# Print the results
print(f"Equilibrium values: Labor demand = {laborD_eq:.4f}, Labor supply = {laborS_eq:.4f}, Good1 = {good1_eq:.4f}, Good2 = {good2_eq:.4f}, Y1 = {y1_eq:.4f}, Y2 = {y2_eq:.4f}")
# Out:
# Equilibrium prices: p1 = 0.9759, p2 = 1.4908
# Equilibrium values: Labor demand = 0.7937, Labor supply = 0.7937, Good1 = 0.4880, Good2 = 0.7454, Y1 = 0.4880, Y2 = 0.7454

# %% [markdown]
# We see that both goods market clears, and thus according to Walras law we know that the market for labor supply and demand must also clear.
# The solutions are thus:
# $c_1=y_1=0.4880$
# $c_2=y_2=0.7454$
# $\ell^\star=0.7937$

# %% [markdown]
# # Question 3
# The government now cares about the social welfare function:
# $$SWF=U-\kappa y_2^\star$$
# We now want to find the value of tax, $\tau$, and lump sum transfers, $T$, that maximizes this function.
# We are told that the governmen balances its budget such that $T=\tau c_2^\star$.

# %%
# Defining an objective function to optimize where the government chooses the optimal tax rate and transfers to maximize the wocial welfare function and the prices clear the markets

def objective_function(x, par):

    tau, p1, p2, T = x

    SW = utility_SWF(par, tau, T, p1, p2) - par.kappa*production(par, p2)

    return -SW

# Initial guess
initial_guess = [-0.1, 1.0, 1.0, 1.0]

# Constraints - Prices have to clear the markets
constraints = ({'type': 'eq', 'fun': lambda x: labor_supply(model.par, x[1], x[2], x[0], x[3]) - labor_demand(model.par, x[1]) - labor_demand(model.par, x[2])},
               {'type': 'eq', 'fun': lambda x: production(model.par, x[2]) - demand(model.par, x[1], x[2], x[0], x[3])[1]},
               {'type': 'eq', 'fun': lambda x: x[3] - x[0] * production(model.par, x[2])})

# Optimize the objective function
optimal_tax = optimize.minimize(objective_function, initial_guess, args=(model.par,), constraints=constraints, method='SLSQP', tol=1e-10)
tau_optimal = optimal_tax.x[0]
p1 = optimal_tax.x[1]
p2 = optimal_tax.x[2]

model.par.tau = tau_optimal
T_optimal = tau_optimal * production(model.par, p2)
model.par.T = T_optimal

# Print the results
print(f"Optimal tax rate: {tau_optimal:.4f}")
print(f"Optimal transfer: {model.par.T:.4f}")
print(f"Optimal prices: p1 = {p1:.4f}, p2 = {p2:.4f}")

gov_budget = T_optimal - tau_optimal * production(model.par, p2)
print(f"Government budget: {gov_budget:.4f}")

laborD_eq = labor_demand(model.par, p1) + labor_demand(model.par, p2)
laborS_eq = labor_supply(model.par, p1, p2, model.par.tau, model.par.T)
good1_eq, good2_eq = demand(model.par, p1, p2, model.par.tau, model.par.T)
y1_eq = production(model.par, p1)
y2_eq = production(model.par, p2)

# Print the results
print(f"Equilibrium values: Labor demand = {laborD_eq:.4f}, Labor supply = {laborS_eq:.4f}, Good1 = {good1_eq:.4f}, Good2 = {good2_eq:.4f}, Y1 = {y1_eq:.4f}, Y2 = {y2_eq:.4f}")
# Out:
# Optimal tax rate: 0.3053
# Optimal transfer: 0.2157
# Optimal prices: p1 = 1.0201, p2 = 1.4130
# Government budget: 0.0000
# Equilibrium values: Labor demand = 0.7593, Labor supply = 0.7593, Good1 = 0.5101, Good2 = 0.7065, Y1 = 0.5101, Y2 = 0.7065

# %% [markdown]
# We see that the optimal tax is $0.3$ while the optimal transfer is $0.2$. This makes the price for good 2 drop to $1.41$ as the demand decreases and the consumers substitutes to good 1.
# Again, we choose to clear the labor market and the market for good 2, as the market for good 1 will then also clear according to Walras' law.
# Likely bacuse of the transfer the consumers now work slightly less, and as expected they consume more of good 1 and less of good 2, compared to question 2.
